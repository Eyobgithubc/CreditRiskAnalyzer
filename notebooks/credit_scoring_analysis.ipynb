# %%
import pandas as pd
import sys
import os

# %%
sys.path.append(os.path.abspath('C:/Users/teeyob/CreditRiskAnalyzer/scripts'))

# %%
from eda_functions import load_data
data=load_data('C:/Users/teeyob/CreditRiskAnalyzer/data/data.csv')

# %%
from eda_functions import data_overview
data_overview(data)
# Out:
# Shape of dataset: (95662, 16)
# Data types:
#  TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object

# %%
from eda_functions import summary_statistics

summary_statistics(data)
# Out:
# ### Summary Statistics
#
# |       |   CountryCode |        Amount |         Value |   PricingStrategy |    FraudResult |
# |:------|--------------:|--------------:|--------------:|------------------:|---------------:|
# | count |         95662 |  95662        |  95662        |      95662        | 95662          |
# | mean  |           256 |   6717.85     |   9900.58     |          2.25597  |     0.00201752 |
# | std   |             0 | 123307        | 123122        |          0.732924 |     0.0448717  |
# | min   |           256 |     -1e+06    |      2        |          0        |     0          |
# | 25%   |           256 |    -50        |    275        |          2        |     0          |
# | 50%   |           256 |   1000        |   1000        |          2        |     0          |
# | 75%   |           256 |   2800        |   5000        |          2        |     0          |
# | max   |           256 |      9.88e+06 |      9.88e+06 |          4        |     1          |

# %% [markdown]
# These histograms illustrate the distributions of transaction amounts, transaction values, and pricing strategies, providing insights into the frequency of each within the dataset.

# %%
from eda_functions import plot_histograms

plot_histograms(data)

# %% [markdown]
# These box plots for transaction amounts and values help visualize the distribution and identify potential outliers in the dataset.

# %%
from eda_functions import plot_box_plots
plot_box_plots(data)

# %% [markdown]
# These count plots visualize the frequency distribution of categorical columns, providing insights into the composition of the dataset.

# %%
from eda_functions import plot_count_plots
plot_count_plots(data)

# %% [markdown]
# This correlation heatmap visualizes the relationships between numerical columns, helping to identify potential correlations within the dataset.

# %%
from eda_functions import plot_correlation_heatmap
plot_correlation_heatmap(data)
